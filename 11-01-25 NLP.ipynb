# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/youtubesample.csv ")

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  m8Dqg8iz5Fo      18.09.05
# 1  2yCp-Dj5-7c      17.16.12
# 2  H00djJq68VE      17.27.12
# 3  oTObwUiXdYY      17.19.11
# 4  yvicqMrAHvQ      18.05.02
#
#                                                title  \
# 0  MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1  Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2  Panettone (Italian Christmas Bread) - Food Wishes
# 3  7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4            Turkish Airlines - 5 Senses with Dr. Oz
#
#                              channel_title  category_id  \
# 0                              Sylvia Gani           26
# 1  Watch What Happens Live with Andy Cohen           24
# 2                              Food Wishes           26
# 3                                     TIME           25
# 4                         Turkish Airlines           19
#
#                publish_time  \
# 0  2018-04-30T00:18:19.000Z
# 1  2017-12-11T04:29:53.000Z
# ...

# %% [markdown]
# iloc(works on index pos) loc(works on index name)

# %%
df.sample(50)
# Out:
#          video_id trending_date  \
# 4642  NjMd89dggAk      18.08.06
# 4798  rhhQS3ns6HU      18.08.02
# 1326  4tpIiSqyiLo      18.30.04
# 1747  3WlhLmh7uiQ      18.08.05
# 4722  XzzQL96yAwE      18.27.04
# 2517  92HCNclQOYo      17.11.12
# 3637  PLAFNvxDPMw      17.22.12
# 2189  PXAZ3KphJz4      18.17.03
# 3173  dc89yyOS0Z8      18.18.04
# 3772  c835XURBeLQ      17.16.12
# 1930  HD5PT7bvcis      18.08.01
# 2268  Tz5L-rNWZBs      18.01.02
# 1495  hv3jeGUv9fY      18.25.04
# 1872  UUkn-enk2RU      18.16.05
# 911   EYkEshCOhEU      17.15.11
# 4357  vOodS7E-SNc      18.11.02
# 4995  bqFjyo7I8fY      18.01.03
# 160   qtW9ornyPIQ      18.02.04
# 2538  CvqtJTrsKCE      18.24.04
# 4297  vU14JY3x81A      17.15.11
# 4627  1PhPYr_9zRY      18.01.06
# 4396  2b5C6Xp3pwA      17.10.12
# 3915  42ZE4DCJkEo      18.09.05
# 603   v2OTO6UEVAo      17.26.12
# 1061  FO6My1joJVc      18.02.05
# 2149  voG07pt-KYI      18.09.06
# 4505  vWYyZMH_QjA      17.16.11
# 2737  odHhIVjDgq8      18.07.02
# ...

# %% [markdown]
# #df.iloc[start :stop :step]

# %%
df.iloc[2 :4 :8]
# Out:
#       video_id trending_date  \
# 2  H00djJq68VE      17.27.12
#
#                                                title channel_title  \
# 2  Panettone (Italian Christmas Bread) - Food Wishes   Food Wishes
#
#    category_id              publish_time  \
# 2           26  2017-12-23T00:07:02.000Z
#
#                                                 tags   views  likes  dislikes  \
# 2  Panettone|"Italian"|"Christmas"|"Bread"|"holid...  283364   8274       332
#
#    comment_count                                  thumbnail_link  \
# 2           1016  https://i.ytimg.com/vi/H00djJq68VE/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 2              False             False                   False
#
#                                          description          Genre
# 2  Learn how to make Panettone! Eaten as is, or t...  Howto & Style

# %%
data.loc[3242:1875:1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3242
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(data.index)
# Out:
# Int64Index([1653, 3278, 2274,  319, 4785, 4743, 4396,  934, 1829, 4143, 4771,
#              903, 1918, 1853, 3229, 1650, 4267, 3688, 4463,  290, 1508, 4325,
#              289, 3009, 3015, 3696, 3387,  624, 2008, 3276,  762, 1227, 3332,
#             1036, 4331,  409, 3533, 2467, 2852, 2378, 2998, 1565, 4761, 2288,
#             1869, 3944, 1090, 4902, 3975, 3879],
#            dtype='int64')

# %%
data.iloc[3242:1875:-1]
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description, Genre]
# Index: []

# %%
data.loc[1653:2274]
# Out:
#          video_id trending_date  \
# 1653  8-Cjsnq8kVU      17.23.11
# 3278  Nz0qoOgyWSQ      17.19.11
# 2274  xwXP7vB4mlY      18.03.03
#
#                                                   title     channel_title  \
# 1653                     Deadpool’s “Wet on Wet” Teaser  20th Century Fox
# 3278  The Talk - Eve Reacts to Nicki Minaj's Racy Ma...          The Talk
# 2274              She Ruined The Surprise Gender Reveal        KKandbabyJ
#
#       category_id              publish_time  \
# 1653            1  2017-11-15T14:01:03.000Z
# 3278           24  2017-11-15T21:24:22.000Z
# 2274           22  2018-02-28T20:43:50.000Z
#
#                                                    tags     views   likes  \
# 1653  Trailer|"Deadpool"|"20th Century Fox (Producti...  12382809  328876
# 3278  The Talk|"Julie Chen"|"Aisha Tyler"|"Sharon Os...    374411    1959
# 2274  kkandbabyj|"khoa"|"keren"|"jackson"|"Landon"|"...    425393   19796
#
# ...

# %% [markdown]
# #Time stamp

# %%
print(data.columns)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'Genre'],
#       dtype='object')

# %%
data['publish_time'] = pd.to_datetime(data['publish_time'])

# %%
filtered_data = data[data['publish_time'] == '2025-01-01']

# %%
filtered_data = data[(data['publish_time'] >= '2025-01-01') & (data['publish_time'] <= '2025-01-10')]

# %%
filtered_data = data[data['publish_time'].dt.hour < 12]

# %%
filtered_data = data[(data['publish_time'].dt.hour == 8)]

# %%
df['channel_title']=='TIME'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: channel_title, Length: 5000, dtype: bool

# %%
df[df['channel_title']=='TIME']
# Out:
#          video_id trending_date  \
# 3     oTObwUiXdYY      17.19.11
# 156   ESKmRiLjNpg      18.19.05
# 302   NuZJQ-YS7_w      18.24.02
# 1385  BR7AnZ3S8u8      17.17.12
# 1590  0XARMt12oFk      17.28.12
# 2866  zsbT6NMUrSk      18.30.01
# 3225  cgYHbIEZWW8      18.22.02
# 4121  ESKmRiLjNpg      18.15.05
#
#                                                   title channel_title  \
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...          TIME
# 156   An Expert's Take On The Symbolism In Childish ...          TIME
# 302   Former Trump Adviser Rick Gates Is About To Pl...          TIME
# 1385  A Federal Judge In Philadelphia Blocks Preside...          TIME
# 1590  Multiple Casualties And Injuries Reported As A...          TIME
# 2866  Judge Aquilina Delivers Powerful Statement Bef...          TIME
# 3225  FBI Admits It Failed To Investigate Tip About ...          TIME
# 4121  An Expert's Take On The Symbolism In Childish ...          TIME
#
# ...

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df[df['views']>= 500000]
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 4     yvicqMrAHvQ      18.05.02
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 9     Biex1XR_mpo      18.24.03
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# 6                           Meghan Trainor - No Excuses
# 7               Marshmello - FLY (Official Music Video)
# 9                50 Mums | 50 Kids | 1 Extra Chromosome
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df[df['comment_count']>= 500000]
# Out:
#          video_id trending_date                                title  \
# 1293  7C2z4GqqS5E      18.30.05  BTS (방탄소년단) 'FAKE LOVE' Official MV
# 4228  7C2z4GqqS5E      18.29.05  BTS (방탄소년단) 'FAKE LOVE' Official MV
# 4394  oWjxSkJpxFU      18.31.01           Suicide: Be Here Tomorrow.
# 4577  7C2z4GqqS5E      18.20.05  BTS (방탄소년단) 'FAKE LOVE' Official MV
# 4967  7C2z4GqqS5E      18.21.05  BTS (방탄소년단) 'FAKE LOVE' Official MV
#
#          channel_title  category_id              publish_time  \
# 1293           ibighit           10  2018-05-18T09:00:02.000Z
# 4228           ibighit           10  2018-05-18T09:00:02.000Z
# 4394  Logan Paul Vlogs           29  2018-01-24T18:30:01.000Z
# 4577           ibighit           10  2018-05-18T09:00:02.000Z
# 4967           ibighit           10  2018-05-18T09:00:02.000Z
#
#                                                    tags      views    likes  \
# 1293  BIGHIT|"빅히트"|"방탄소년단"|"BTS"|"BANGTAN"|"방탄"|"FAK...  115664850  5530568
# ...

# %%
(df['sex']=='') & df['comment_count']>5000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %% [markdown]
# for all conditions pipe symbol |
# for and & symbol

# %%
df[(df['channel_title']=='TIME') & (df['comment_count']>500)]
# Out:
#          video_id trending_date  \
# 156   ESKmRiLjNpg      18.19.05
# 1590  0XARMt12oFk      17.28.12
# 2866  zsbT6NMUrSk      18.30.01
# 3225  cgYHbIEZWW8      18.22.02
# 4121  ESKmRiLjNpg      18.15.05
#
#                                                   title channel_title  \
# 156   An Expert's Take On The Symbolism In Childish ...          TIME
# 1590  Multiple Casualties And Injuries Reported As A...          TIME
# 2866  Judge Aquilina Delivers Powerful Statement Bef...          TIME
# 3225  FBI Admits It Failed To Investigate Tip About ...          TIME
# 4121  An Expert's Take On The Symbolism In Childish ...          TIME
#
#       category_id              publish_time  \
# 156            25  2018-05-08T17:52:37.000Z
# 1590           25  2017-12-18T18:26:52.000Z
# 2866           25  2018-01-24T20:24:08.000Z
# 3225           25  2018-02-16T18:45:03.000Z
# 4121           25  2018-05-08T17:52:37.000Z
#
# ...
