# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# ...
#      ---------------------------------------- 12.2/12.2 MB 5.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 183.0/183.0 kB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 3.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 50.3/50.3 kB 2.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 431.4/431.4 kB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 632.3/632.3 kB 6.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 44.9/44.9 kB 2.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 122.2/122.2 kB 7.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.4/5.4 MB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.0/2.0 MB 2.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.2/6.2 MB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 52.5/52.5 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Gender']=='male') & (df['Age']>50)].count()
# Out:
# PassengerId    47
# Survived       47
# Pclass         47
# Name           47
# Gender         47
# Age            47
# SibSp          47
# Parch          47
# Ticket         47
# Fare           47
# Cabin          20
# Embarked       47
# dtype: int64

# %%
df[(df['Gender']=='male') & (df['Age']>50)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 94            95         0       3                     Coxon, Mr. Daniel
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 124          125         0       1           White, Mr. Percival Wayland
# 150          151         0       2            Bateman, Rev. Robert James
# 152          153         0       3                      Meo, Mr. Alfonzo
# 155          156         0       1           Williams, Mr. Charles Duane
# 170          171         0       1             Van der hoef, Mr. Wyckoff
# 174          175         0       1               Smith, Mr. James Clinch
# ...

# %%
df[(df['Gender']=='male') & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                             Name Gender  \
# 17            18         1       2     Williams, Mr. Charles Eugene   male
# 21            22         1       2            Beesley, Mr. Lawrence   male
# 23            24         1       1     Sloper, Mr. William Thompson   male
# 36            37         1       3                 Mamee, Mr. Hanna   male
# 55            56         1       1                Woolner, Mr. Hugh   male
# ..           ...       ...     ...                              ...    ...
# 838          839         1       3                  Chip, Mr. Chang   male
# 839          840         1       1             Marechal, Mr. Pierre   male
# 857          858         1       1           Daly, Mr. Peter Denis    male
# 869          870         1       3  Johnson, Master. Harold Theodor   male
# 889          890         1       1            Behr, Mr. Karl Howell   male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df[(df['Gender']=='male') & (df['Survived']==1)].count()
# Out:
# PassengerId    109
# Survived       109
# Pclass         109
# Name           109
# Gender         109
# Age             93
# SibSp          109
# Parch          109
# Ticket         109
# Fare           109
# Cabin           45
# Embarked       109
# dtype: int64

# %%
df[(df['Gender']=='female') & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Gender']=='female') & (df['Survived']==1)].count()
# Out:
# PassengerId    233
# Survived       233
# Pclass         233
# Name           233
# Gender         233
# Age            197
# SibSp          233
# Parch          233
# Ticket         233
# Fare           233
# Cabin           91
# Embarked       231
# dtype: int64

# %% [markdown]
# # SURVIVAL RATE OF MALE = 109/577*100 = 18.89%
# # SURVIVAL RATE OF FEMALE = 74%.

# %%
#UPDATE FARE PRICES BY 500 WHERE AGE IS GREATER THAN 55
df[df['Age']>55]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 152          153         0       3
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 232          233         0       2
# 252          253         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 467          468         0       1
# 483          484         1       3
# 487          488         0       1
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# ...

# %%
df.loc[df['Age'] > 55, 'Fare'] = 500

# %%
df[df['Age']>55]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 152          153         0       3
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 232          233         0       2
# 252          253         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 467          468         0       1
# 483          484         1       3
# 487          488         0       1
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# ...

# %%
#update fare values of pclass 1 who have more than 2 sibsp 
df[(df['Pclass'] == 1) & (df['SibSp'] > 2)] #filter
# Out:
#      PassengerId  Survived  Pclass                            Name  Gender  \
# 27            28         0       1  Fortune, Mr. Charles Alexander    male
# 88            89         1       1      Fortune, Miss. Mabel Helen  female
# 341          342         1       1  Fortune, Miss. Alice Elizabeth  female
#
#       Age  SibSp  Parch Ticket   Fare        Cabin Embarked
# 27   19.0      3      2  19950  263.0  C23 C25 C27        S
# 88   23.0      3      2  19950  263.0  C23 C25 C27        S
# 341  24.0      3      2  19950  263.0  C23 C25 C27        S

# %%
df.loc[(df['Pclass']==1) & (df['SibSp']>2),'Fare']=1000

# %%
df[(df['Gender'] == 'female') & (df['Pclass'] == 1)] #filteration
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # increase fare prices by 30 percent where gender is female and pclass is 1

# %%
df.loc[(df['Gender'] == 'female') & (df['Pclass'] == 1), 'Fare'] *= 1.3

# %%
print(updated_fares[['Gender', 'Pclass', 'Fare']])
# Out:
#      Gender  Pclass         Fare
# 1    female       1   156.609410
# 3    female       1   116.660700
# 11   female       1  1098.500000
# 31   female       1   321.906198
# 52   female       1   168.574052
# ..      ...     ...          ...
# 856  female       1   362.212140
# 862  female       1    56.966452
# 871  female       1   115.461577
# 879  female       1  1098.500000
# 887  female       1    65.910000
#
# [94 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #updation

# %%
df['Age'].mean()
# Out:
# 29.36158249158249

# %%
df['Age'].mode()
# Out:
# 0    28.0
# Name: Age, dtype: float64

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df.loc[df['Age'].isnull(),'Age']=29.69

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.loc[df['Embarked'].isnull(),'Embarked']=0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df['Cabin'].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %% [markdown]
# # when we have outliers we should use MEDIAN
# # when we have DO NO HAVE outliers we should use MEDIAN/MEAN

# %% [markdown]
# m
